# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
rc("text", usetex=True)

# %%
# Our conformal transformation
def w(z):
    return np.sqrt(z**2 + 1000)

# %%
# The x and y coordinates
Xv=np.linspace(0,1,300)
Yv=np.linspace(0,1,300)
X,Y=np.meshgrid(Xv,Yv)
# Values of w as a function of z=x+iy
Wv=w(X+1j*Y)

# %%
lv=np.linspace(0,1,1000)
# Contours of constant Re[w] and Im[w] as a function of x and y
plt.contour(Xv,Yv,np.real(Wv),colors='b',linestyles='solid',levels=lv)
plt.contour(Xv,Yv,np.imag(Wv),colors='b',linestyles='solid',levels=lv)
# Out:
# <ipython-input-28-d4ece324ecac>:3: UserWarning: No contour levels were found within the data range.
#   plt.contour(Xv,Yv,np.real(Wv),colors='b',linestyles='solid',levels=lv)

# %%
# %run api.py

# constants
PI = np.pi
TAU = 2 * PI
HALF_PI = PI / 2

# %%
grid = init_grid()
plot_map(grid, map=None)
# Out:
# <AxesSubplot:>
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     274         try:
# --> 275             report = subprocess.check_output(command,
#     276                                              cwd=self.texcache,
#
# /usr/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410
# --> 411     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     412                **kwargs).stdout
#
# /usr/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     511         if check and retcode:
# --> 512             raise CalledProcessError(retcode, process.args,
#     513                                      output=stdout, stderr=stderr)
#
# ...
